# %%
import torch

# %%
distances = torch.tensor([[1.0],[2.0],[3.0],[4.0]], dtype=torch.float32)

# %%
# let's look at shape
distances.shape
# Out:
# torch.Size([4, 1])

# %% [markdown]
# ```
# # [4,
# #    1 - number of features
# ```

# %%
# using unsqueeze to add dimension
dist = torch.tensor(25.0)
dist.shape
# Out:
# torch.Size([])

# %%
with_batch = dist.unsqueeze(0)
with_batch.shape
# Out:
# torch.Size([1])

# %%
ready_for_model = with_batch.unsqueeze(1)
ready_for_model.shape
# Out:
# torch.Size([1, 1])

# %%
print(dist, with_batch, ready_for_model)
# Out:
# tensor(25.) tensor([25.]) tensor([[25.]])

# %%
ready_for_model.squeeze()
# Out:
# tensor(25.)

# %%
ready_for_model.squeeze().squeeze()
# Out:
# tensor(25.)
